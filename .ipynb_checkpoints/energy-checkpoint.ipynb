# %% [markdown]
# <h3>Energy Analysis</h3>
# Explore account and energy pricing data from Octopus Energy

# %%
# script setup
import energy as e
import private as my
e.account_setting(api_key=my.octopus_api_key, imp=my.imp_meter, gas=my.gas_meter, exp=my.exp_meter,debug=1)
e.solcast_setting(api_key=my.solcast_api_key, rids=my.rids, save='forecasts.json')
e.period_setting('night', start='0130', end='0500')
e.period_setting('pm', start='1230', end='1600')
# Out:
# Octopus credentials provided
# Solcast credentials provided

# %%
p = e.Product('AGILE-FLEX-22')
print(p)
p.plot_30_minute_prices(days=10)
# Out:
# Product details for code: AGILE-FLEX-22-11-25
#    Display name:      Agile Octopus
#    Full name:         Agile Octopus November 2022 v1
#    Description:       With Agile Octopus, you get access to half-hourly energy prices, tied to wholesale prices and updated daily.  The unit rate is capped at 100
#    Available from:    2022-11-25T00:00:00Z
#    Available to:      None
#    Your region (GSP): Southern England
#    Import price code: E-1R-AGILE-FLEX-22-11-25-H
#    Import day rate:   42.7665 p/day inc VAT
#    Average import prices inc VAT for 10 days to  2023-02-24:
#        Night off peak:      22.16 p/kwh (0130 to 0459)
#        Morning peak:        30.56 p/kwh (0600 to 0959)
#        Afternoon off peak:  26.32 p/kwh (1230 to 1559)
#        Evening peak:        34.23 p/kwh (1600 to 1859)

# %%
p.plot_30_minute_prices(days=1)
# Out:
#    Average import prices inc VAT for  2023-02-24:
#        Night off peak:      26.48 p/kwh (0130 to 0459)
#        Morning peak:        31.74 p/kwh (0600 to 0959)
#        Afternoon off peak:  27.34 p/kwh (1230 to 1559)
#        Evening peak:        34.23 p/kwh (1600 to 1859)

# %%
p = e.Product('AGILE-OUT')
print(p)
p.plot_30_minute_prices(days=1)
# Out:
# Product details for code: AGILE-OUTGOING-19-05-13
#    Display name:      Agile Outgoing Octopus
#    Full name:         Agile Outgoing Octopus May 2019
#    Description:       Outgoing Octopus Agile rate pays you for all your exported energy based on the day-ahead wholesale rate.
#    Available from:    2018-01-01T00:00:00Z
#    Available to:      None
#    Term:              12 months
#    Your region (GSP): Southern England
#    Export price code: E-1R-AGILE-OUTGOING-19-05-13-H
#    Export day cost:   0.0 p/day inc VAT
#    Average export prices for  2023-02-24:
#        Night off peak:      12.22 p/kwh (0130 to 0459)
#        Morning peak:        14.49 p/kwh (0600 to 0959)
#        Afternoon off peak:  12.59 p/kwh (1230 to 1559)
#        Evening peak:        22.14 p/kwh (1600 to 1859)

# %%
f = e.Forecast(reload=0)
print(f)
f.plot_estimate()
# Out:
# Solcast yield forecast for next 14 days:
#
#     02-26 Sun : 11.01 kwh
#     02-27 Mon :  5.21 kwh
#     02-28 Tue :  5.33 kwh
#     03-01 Wed :  9.84 kwh
#     03-02 Thu : 15.61 kwh
#     03-03 Fri : 10.74 kwh
#     03-04 Sat : 10.92 kwh
#     03-05 Sun :  7.09 kwh
#     03-06 Mon :  6.53 kwh
#     03-07 Tue :  6.69 kwh
#     03-08 Wed :  7.41 kwh
#     03-09 Thu : 12.15 kwh
#     03-10 Fri :  6.98 kwh
#     03-11 Sat :  9.08 kwh
