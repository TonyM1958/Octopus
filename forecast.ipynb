# %% [markdown]
# <h3>Solar Forecast</h3>
#
# Get 13 day solar forecast from your Solcast account / resource ids.

# %%
# get_new: 0 = use cached forecast,  1 = fetch new data.
get_new = 0

# run forecast
import private as my
import energy as e
e.account_setting(debug=1)
e.solcast_setting(api_key=my.solcast_api_key, rids=my.rids, save='solcast.json')
f = e.Solcast(reload=get_new)
print(f)
f.plot_daily()
# Out:
# Solcast credentials provided
#
# Solcast yield for 13 days (E = estimated, F = forecasts):
#
#     2023-05-19 Fri E: 23.47 kwh
#     2023-05-20 Sat E: 38.11 kwh
#     2023-05-21 Sun E: 37.83 kwh
#     2023-05-22 Mon E: 31.33 kwh
#     2023-05-23 Tue E: 28.79 kwh
#     2023-05-24 Wed E: 38.62 kwh
#     2023-05-25 Thu F: 34.45 kwh
#     2023-05-26 Fri F: 39.43 kwh
#     2023-05-27 Sat F: 40.41 kwh
#     2023-05-28 Sun F: 30.08 kwh
#     2023-05-29 Mon F: 34.26 kwh
#     2023-05-30 Tue F: 39.20 kwh
#     2023-05-31 Wed F: 34.30 kwh
