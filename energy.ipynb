# %% [markdown]
# <h3>Energy Analysis</h3>
# Explore account and energy pricing data from Octopus Energy

# %%
# script setup
import private as my
import energy as e
e.account_setting(api_key=my.octopus_api_key, imp=my.imp_meter, gas=my.gas_meter, exp=my.exp_meter,debug=1)
e.solcast_setting(api_key=my.solcast_api_key, rids=my.rids, save='solcast.json')
e.period_setting('night', start='0130', end='0500')
e.period_setting('pm', start='1230', end='1600')
# Out:
# Octopus credentials provided
# Solcast credentials provided

# %%
p = e.Product('AGILE-FLEX-22')
print(p)
p.plot_30_minute_prices(days=7)
# Out:
# Product details for code: AGILE-FLEX-22-11-25
#    Display name:      Agile Octopus
#    Full name:         Agile Octopus November 2022 v1
#    Description:       With Agile Octopus, you get access to half-hourly energy prices, tied to wholesale prices and update
#    Available from:    2022-11-25T00:00:00Z
#    Available to:      None
#    Your region (GSP): Southern England
#    Import price code: E-1R-AGILE-FLEX-22-11-25-H
#    Import day rate:   42.7665 p/day inc VAT
#    Period average import prices inc VAT in p/kwh for 7 days from 2023-02-20 to 2023-02-26
#        Night off peak:      23.96 p/kwh (0130 to 0459)
#        Morning peak:        30.25 p/kwh (0600 to 0959)
#        Afternoon off peak:  27.19 p/kwh (1230 to 1559)
#        Evening peak:        34.23 p/kwh (1600 to 1859)

# %%
p.plot_30_minute_prices(days=2)
# Out:
#    Period average import prices inc VAT in p/kwh for 2 days from 2023-02-25 to 2023-02-26
#        Night off peak:      26.13 p/kwh (0130 to 0459)
#        Morning peak:        27.88 p/kwh (0600 to 0959)
#        Afternoon off peak:  29.19 p/kwh (1230 to 1559)
#        Evening peak:        34.23 p/kwh (1600 to 1859)

# %%
p = e.Product('AGILE-OUT')
print(p)
p.plot_30_minute_prices(days=1)
# Out:
# Product details for code: AGILE-OUTGOING-19-05-13
#    Display name:      Agile Outgoing Octopus
#    Full name:         Agile Outgoing Octopus May 2019
#    Description:       Outgoing Octopus Agile rate pays you for all your exported energy based on the day-ahead wholesale r
#    Available from:    2018-01-01T00:00:00Z
#    Available to:      None
#    Term:              12 months
#    Your region (GSP): Southern England
#    Export price code: E-1R-AGILE-OUTGOING-19-05-13-H
#    Export day cost:   0.0 p/day inc VAT
#    Period average export prices in p/kwh for 2023-02-26
#        Night off peak:      12.13 p/kwh (0130 to 0459)
#        Morning peak:        12.18 p/kwh (0600 to 0959)
#        Afternoon off peak:  13.57 p/kwh (1230 to 1559)
#        Evening peak:        22.86 p/kwh (1600 to 1859)

# %%
f = e.Forecast(reload=0)
print(f)
f.plot_daily()
# Out:
# Solcast yield over 15 days (A = actuals, F = forecasts):
#
#     2023-02-26 Sun F:  7.88 kwh
#     2023-02-27 Mon F:  5.61 kwh
#     2023-02-28 Tue F:  5.79 kwh
#     2023-03-01 Wed F:  9.81 kwh
#     2023-03-02 Thu F: 15.48 kwh
#     2023-03-03 Fri F:  8.89 kwh
#     2023-03-04 Sat F:  8.33 kwh
#     2023-03-05 Sun F:  8.51 kwh
#     2023-03-06 Mon F: 10.89 kwh
#     2023-03-07 Tue F: 11.34 kwh
#     2023-03-08 Wed F: 15.77 kwh
#     2023-03-09 Thu F: 17.47 kwh
#     2023-03-10 Fri F: 16.68 kwh
#     2023-03-11 Sat F:  5.79 kwh
#     2023-03-12 Sun F:  3.47 kwh
