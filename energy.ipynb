# %% [markdown]
# <h3>Energy Analysis</h3>
# Explore account and energy pricing data from Octopus Energy

# %%
# script setup
import energy as e
import private as my
e.account_setting(api_key=my.octopus_api_key, imp=my.imp_meter, gas=my.gas_meter, exp=my.exp_meter,debug=1)
e.solcast_setting(api_key=my.solcast_api_key, rids=my.rids, save='forecasts.json')
e.period_setting('night', start='0130', end='0500')
e.period_setting('pm', start='1230', end='1600')
# Out:
# Octopus credentials provided
# Solcast credentials provided

# %%
p = e.Product('AGILE-FLEX-BB')
print(p)
p.plot_30_minute_prices(days=7)
# Out:
# Product details for code: AGILE-FLEX-BB-23-02-08
#    Display name:      Agile Octopus
#    Full name:         Agile Octopus February 2023 v1
#    Description:       With Agile Octopus, you get access to half-hourly energy prices, tied to wholesale prices and updated daily.  The unit rate is capped at 100
#    Available from:    2023-02-08T00:00:00Z
#    Available to:      None
#    Your region (GSP): Southern England
#    Import price code: E-1R-AGILE-FLEX-BB-23-02-08-H
#    Import day rate:   42.7665 p/day inc VAT
#    Average import prices inc VAT over last 7 days:
#        Night time off peak: 23.80 p/kwh (0130 to 0459)
#        Morning peak:        31.04 p/kwh (0630 to 1029)
#        Afternoon off peak:  26.11 p/kwh (1230 to 1559)
#        Evening peak:        33.90 p/kwh (1600 to 1959)

# %%
p = e.Product('AGILE-OUT')
print(p)
p.plot_30_minute_prices(days=1)
# Out:
# Product details for code: AGILE-OUTGOING-19-05-13
#    Display name:      Agile Outgoing Octopus
#    Full name:         Agile Outgoing Octopus May 2019
#    Description:       Outgoing Octopus Agile rate pays you for all your exported energy based on the day-ahead wholesale rate.
#    Available from:    2018-01-01T00:00:00Z
#    Available to:      None
#    Term:              12 months
#    Your region (GSP): Southern England
#    Export price code: E-1R-AGILE-OUTGOING-19-05-13-H
#    Export day cost:   0.0 p/day inc VAT
#    Average export prices over last 7 days:
#        Night time off peak: 11.08 p/kwh (0130 to 0459)
#        Morning peak:        14.26 p/kwh (0630 to 1029)
#        Afternoon off peak:  12.06 p/kwh (1230 to 1559)
#        Evening peak:        20.33 p/kwh (1600 to 1959)

# %%
f = e.Forecast(reload=0)
print(f)
f.plot_estimate()
# Out:
# Solcast yield forecast for next 14 days:
#
#     02-25 Sat : 10.56 kwh
#     02-26 Sun : 13.37 kwh
#     02-27 Mon : 11.44 kwh
#     02-28 Tue : 12.97 kwh
#     03-01 Wed :  8.23 kwh
#     03-02 Thu : 14.87 kwh
#     03-03 Fri :  9.22 kwh
#     03-04 Sat : 14.17 kwh
#     03-05 Sun :  9.66 kwh
#     03-06 Mon : 13.12 kwh
#     03-07 Tue :  6.95 kwh
#     03-08 Wed :  6.95 kwh
#     03-09 Thu :  5.96 kwh
#     03-10 Fri :  3.70 kwh
