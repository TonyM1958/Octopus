# %% [markdown]
# <h3>Energy Analysis</h3>
# Explore account and energy pricing data from Octopus Energy

# %%
import energy as e

# %%
e.account_setting(api_key='sk_live_hVJH9aBwRBjpBmByIOoeBYbJ', imp=e.Meter('2000012106021','17M1027563'), gas=e.Meter('4263963306','G4F72314901700'),exp=e.Meter('2000060236259', '17M1027563'))
p = e.Product('AGILE-FLEX-BB')
print(p)
p.plot_30_minute_prices()
# Out:
# 2000012106021 / 17M1027563 validated
# Credentials set
# Electricity: MPAN=2000012106021, serial=17M1027563, gsp=_H
# Export: MPAN=2000060236259, serial=17M1027563, gsp=_H
# Gas: MPRN=4263963306, serial=G4F72314901700, gsp=_H
# code: AGILE-FLEX-BB-23-02-08   display_name:   Agile Octopus
#    full_name:      Agile Octopus February 2023 v1
#    description:    With Agile Octopus, you get access to half-hourly energy prices, tied to wholesale prices and updated daily.  The unit rate is capped at 100p/kWh (including VAT).
#    is_variable:    True
#    is_green:       True
#    is_outgoing:    False
#    term:           None
#    available_from: 2023-02-08T00:00:00Z
#    available_to:   None
#    imp_code:       E-1R-AGILE-FLEX-BB-23-02-08-H
#    imp_day:        42.7665 p/day
#    imp_kwh:        34.22601 p/kwh

# %%
p = e.Product('VAR')
print(p)
p.plot_30_minute_prices()
# Out:
# code: VAR-22-10-01   display_name:   Flexible Octopus
#    full_name:      Flexible Octopus October 2022 v1
#    description:    Flexible Octopus offers great value and 100% renewable electricity. As a variable tariff, your prices can rise and fall with wholesale prices - but we'll always give you notice of a change.
#    is_variable:    True
#    is_green:       False
#    is_outgoing:    False
#    term:           None
#    available_from: 2022-09-21T00:00:00+01:00
#    available_to:   None
#    imp_code:       E-1R-VAR-22-10-01-H
#    imp_day:        42.76965 p/day
#    imp_kwh:        34.22601 p/kwh
#    gas_code:       G-1R-VAR-22-10-01-H
#    gas_day:        26.84136 p/day
#    gas_kwh:        10.45758 p/kwh
#
# ** no 30 minute pricing for Flexible Octopus October 2022 v1 (VAR-22-10-01)

# %%
e.solcast_setting(api_key='0j3U24A6RqDkMVkYFm4kc3ThxtFWuc2C', rids=['d633-d82c-f6d7-5f01','9d85-2347-e8eb-ee72'], save='forecasts.json')
f = e.Forecast()
f.plot_estimate()
print(f)
# Out:
# Solcast credentials set
# Solcast resource ids: ['d633-d82c-f6d7-5f01', '9d85-2347-e8eb-ee72']
# Solcast yield forecast for next 14 days:
#
#     02-23 Thu : 10.19 kwh
#     02-24 Fri :  6.01 kwh (below threshold)
#     02-25 Sat : 10.91 kwh
#     02-26 Sun : 15.04 kwh
#     02-27 Mon : 13.02 kwh
#     02-28 Tue : 15.36 kwh
#     03-01 Wed :  9.90 kwh (below threshold)
#     03-02 Thu :  8.85 kwh (below threshold)
#     03-03 Fri : 13.34 kwh
#     03-04 Sat : 11.99 kwh
#     03-05 Sun : 12.60 kwh
#     03-06 Mon : 18.61 kwh
#     03-07 Tue : 18.65 kwh
#     03-08 Wed : 15.31 kwh
