# %% [markdown]
# <h3>Energy Analysis</h3>
# Explore account and energy pricing data from Octopus Energy

# %%
# script setup
import energy as e
import private as my
e.account_setting(api_key=my.octopus_api_key, imp=my.imp_meter, gas=my.gas_meter, exp=my.exp_meter,debug=1)
e.solcast_setting(api_key=my.solcast_api_key, rids=my.rids, save='forecasts.json')
# Out:
# Octopus credentials provided
# Solcast credentials provided

# %%
p = e.Product('AGILE-FLEX-BB', days=7)
print(p)
# Out:
# Product details for code: AGILE-FLEX-BB-23-02-08
#    Display name:      Agile Octopus
#    Full name:         Agile Octopus February 2023 v1
#    Description:       With Agile Octopus, you get access to half-hourly energy prices, tied to wholesale prices and updated daily.  The unit rate is capped at 100p/kWh (including VAT).
#    Is variable:       True
#    Is green:          True
#    Is outgoing:       False
#    Term:              None months
#    Available from:    2023-02-08T00:00:00Z
#    Available to:      None
#    Your region (GSP): Southern England
#    Import price code: E-1R-AGILE-FLEX-BB-23-02-08-H
#    Import day rate:   42.7665 p/day
#    Import unit cost:  34.22601 p/kwh

# %%
e.period_setting('night', start='0130', end='0500')
e.period_setting('pm', start='1230', end='1600')
p.plot_30_minute_prices()
# Out:
#   Night time off peak average unit price:  23.80 p/kwh (0130 to 0459)
#   Morning peak average unit price:         31.04 p/kwh (0630 to 1029)
#   Afternoon off peak average unit price:   26.11 p/kwh (1230 to 1559)
#   Evening peak average unit price:         33.90 p/kwh (1600 to 1959)

# %%
p = e.Product('VAR')
print(p)
p.plot_30_minute_prices()
# Out:
# Product details for code: VAR-22-10-01
#    Display name:      Flexible Octopus
#    Full name:         Flexible Octopus October 2022 v1
#    Description:       Flexible Octopus offers great value and 100% renewable electricity. As a variable tariff, your prices can rise and fall with wholesale prices - but we'll always give you notice of
#    Is variable:       True
#    Is green:          False
#    Is outgoing:       False
#    Term:              None months
#    Available from:    2022-09-21T00:00:00+01:00
#    Available to:      None
#    Your region (GSP): Southern England
#    Import price code: E-1R-VAR-22-10-01-H
#    Import day rate:   42.76965 p/day
#    Import unit cost:  34.22601 p/kwh
#    Gas price code:    G-1R-VAR-22-10-01-H
#    Gas day cost:      26.84136 p/day
#    Gas unit cost:     10.45758 p/kwh
# ** no 30 minute pricing for Flexible Octopus October 2022 v1 (VAR-22-10-01)

# %%
f = e.Forecast(reload=0)
f.plot_estimate()
print(f)
# Out:
# Solcast yield forecast for next 14 days:
#
#     02-25 Sat : 10.56 kwh
#     02-26 Sun : 13.37 kwh
#     02-27 Mon : 11.44 kwh
#     02-28 Tue : 12.97 kwh
#     03-01 Wed :  8.23 kwh
#     03-02 Thu : 14.87 kwh
#     03-03 Fri :  9.22 kwh
#     03-04 Sat : 14.17 kwh
#     03-05 Sun :  9.66 kwh
#     03-06 Mon : 13.12 kwh
#     03-07 Tue :  6.95 kwh
#     03-08 Wed :  6.95 kwh
#     03-09 Thu :  5.96 kwh
#     03-10 Fri :  3.70 kwh
